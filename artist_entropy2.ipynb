# %%
import pandas as pd
import json as js
import numpy as np
import math
from scipy.stats import entropy
import time

# %%
df=pd.read_csv('msno_entropy_max_rate',sep=',')
df
# Out:
#                    msno  artist_id  count_number  sum_count_number  \
# 0                     7       14.0           1.0              73.0
# 1                     7      584.0           5.0              73.0
# 2                     7     1139.0           1.0              73.0
# 3                     7     3404.0           5.0              73.0
# 4                     7     5301.0           1.0              73.0
# 5                     7     6650.0           2.0              73.0
# 6                     7     6651.0          11.0              73.0
# 7                     7     9423.0           2.0              73.0
# 8                     7    11476.0           1.0              73.0
# 9                     7    14424.0           2.0              73.0
# 10                    7    18153.0           1.0              73.0
# 11                    7    25560.0           1.0              73.0
# 12                    7    29702.0           3.0              73.0
# ...

# %%
df2=df.groupby(['artist_id','msno'])['count_number'].sum()
df2=df2.reset_index()
df2=df2.sort_values('artist_id',ascending=False)
df2

# %%
#df3=df2.groupby('msno')['count_number'].sum()
#df3=df3.reset_index()
#df3
df2['count_msno_total']=df2.groupby("msno")["count_number"].transform("sum")
df2

# %%
df2['msno_proportion']=df2['count_number']/df2['count_msno_total']
df2['w']=df2['count_number'] * df2['msno_proportion']
df2

# %%
df2['sum_score']=df2.groupby("artist_id")["w"].transform("sum")
df2

# %%
df2['count_msno_number']=df2.groupby("artist_id")["msno"].transform("count")
df2

# %%
df2['score_avg']=df2['sum_score']/df2['count_msno_number']
df2

# %%
df2.sort_values('score_avg',ascending=False).drop_duplicates(['artist_id'], keep='last')

# %%
df2[df2['artist_id']==5603802]

# %%
df=df.sort_values('each_artist_entrop',ascending=False).drop_duplicates(['msno'], keep='last')
df

# %%
#df3=df2.sort_values('score_avg',ascending=False).drop_duplicates(['artist_id'], keep='last')
#df3

# %%
#df4.to_csv('msno_entrop.csv',sep=',',encoding='utf-8',index=False)

# %%
#df3.to_csv('artist_entrop.csv',sep=',',encoding='utf-8',index=False)

# %%
len(df[(df['each_artist_entrop']>0) & (df['each_artist_entrop']<0.9)])
#df4
# Out:
# 111994586

# %%
len(df[(df['each_artist_entrop']>0) & (df['each_artist_entrop']<0.8)])
#df4
# Out:
# 106768767

# %%
len(df[(df['each_artist_entrop']>0) & (df['each_artist_entrop']<0.7)])
#df4
# Out:
# 99387236

# %%
len(df[(df['each_artist_entrop']>0) & (df['each_artist_entrop']<0.6)])
#df4
# Out:
# 88612237

# %%
len(df[(df['each_artist_entrop']>0) & (df['each_artist_entrop']<0.5)])
#df4
# Out:
# 72865129

# %%
len(df[(df['each_artist_entrop']>0) & (df['each_artist_entrop']<0.4)])
#df4
# Out:
# 50757618

# %%
len(df[(df['each_artist_entrop']>0) & (df['each_artist_entrop']<0.3)])
#df4
# Out:
# 23643251

# %%
len(df[(df['each_artist_entrop']>0) & (df['each_artist_entrop']<0.2)])
#df4
# Out:
# 3393919

# %%
len(df[(df['each_artist_entrop']>0) & (df['each_artist_entrop']<0.1)])
#df4
# Out:
# 27869

# %%
ff=df3[df3['score_avg']<=5]

# %%
#ff.to_csv('tess_Artist',sep=',',encoding='utf-8',index=False)

# %%
del df4
